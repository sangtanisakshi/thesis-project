# %% [markdown]
# # Usage Example
#
# In this notebook we will show the most basic usage of **TGAN** in order to generate samples from a
# given dataset.

# %% [markdown]
# ### 1. Load the data
#
# The first step is to load the data wich we will use to fit TGAN. In order to do so, we will first
# import the function `tgan.data.load_data` and call it with the name the dataset that we want to load.
#
# In this case, we will load the `census` dataset, which we will use during the subsequent steps, and obtain two objects:
#
# 1. `data` will contain a `pandas.DataFrame` with the table of data from the `census` dataset ready to be used to fit the model.
#
# 2. `continous_columns` will contain a `list` with the indices of continuous columns.

# %%
from tgan.data import load_demo_data
import pandas as pd

data = pd.DataFrame(pd.read_csv('../thesisGAN/input/sub_data_temporal.csv'))
continuous_columns = ['duration','date_first_seen','packets','bytes']
data.head(3).T
# Out:
#                                        0                        1  \
# Unnamed: 0                             0                        1
# date_first_seen  2017-03-17 14:19:09.708  2017-03-17 14:19:09.708
# duration                             0.0                      0.0
# proto                                TCP                      TCP
# packets                                1                        1
# bytes                               46.0                     40.0
# tcp_con                                0                        0
# tcp_ech                                0                        0
# tcp_urg                                0                        0
# tcp_ack                                0                        1
# tcp_psh                                0                        0
# tcp_rst                                0                        1
# tcp_syn                                1                        0
# tcp_fin                                0                        0
# tos                                    0                        0
# label                         suspicious               suspicious
# attack_type                       benign                   benign
# attack_id                              0                        0
#
#                                        2
# Unnamed: 0                             2
# date_first_seen  2017-03-17 14:21:48.203
# duration                             0.0
# proto                                TCP
# packets                                1
# bytes                               46.0
# tcp_con                                0
# tcp_ech                                0
# tcp_urg                                0
# tcp_ack                                0
# tcp_psh                                0
# tcp_rst                                0
# tcp_syn                                1
# tcp_fin                                0
# tos                                    0
# label                         suspicious
# attack_type                       benign
# attack_id                              0

# %%
continuous_columns

# %% [markdown]
# ### 2. Create a TGAN instance
#
# The next step is to import TGAN and create an instance of the model.
#
# To do so, we need to import the `tgan.model.TGANModel` class and call it.
#
# This will create a TGAN instance with the default parameters.

# %%
import tensorflow as tf
# Out:
# c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\tensorflow\python\framework\dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\tensorflow\python\framework\dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\tensorflow\python\framework\dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\tensorflow\python\framework\dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0'

# %%
tf.test.gpu_device_name()

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))

# %%
from tgan.model import TGANModel
import tensorflow as tf
tgan = TGANModel(
    continuous_columns,
    output='output',
    gpu='0',
    max_epoch=5,
    steps_per_epoch=10000,
    save_checkpoints=True,
    restore_session=True,
    batch_size=64,
    z_dim=200,
    noise=0.2,
    l2norm=0.00001,
    learning_rate=0.001,
    num_gen_rnn=100,
    num_gen_feature=100,
    num_dis_layers=1,
    num_dis_hidden=100,
    optimizer='AdamOptimizer'
)

# %% [markdown]
# ### 3. Fit the model
#
# The third step is to pass the data that we have loaded previously to the `TGANModel.fit` method to
# start the fitting.
#
# This process will not return anything, however, the progress of the fitting will be printed into screen.
#
# **NOTE** Depending on the performance of the system you are running, and the parameters selected
# for the model, this step can take up to a few hours.

# %%
tgan.fit(data)
# Out:
# [0305 11:28:19 @input_source.py:222] Setting up the queue 'QueueInput/input_queue' for CPU prefetching ...
# WARNING:tensorflow:From c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From c:\Users\cupca\Desktop\Thesis\thesis-project\TGAN\tgan\model.py:259: LSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# [0305 11:28:19 @registry.py:126] gen/LSTM/00/FC input: [64, 100]
# [0305 11:28:19 @registry.py:134] gen/LSTM/00/FC output: [64, 100]
# [0305 11:28:19 @registry.py:126] gen/LSTM/00/FC2 input: [64, 100]
# [0305 11:28:19 @registry.py:134] gen/LSTM/00/FC2 output: [64, 2393572]
# [0305 11:28:19 @registry.py:126] gen/LSTM/00/FC3 input: [64, 2393572]
# [0305 11:28:19 @registry.py:134] gen/LSTM/00/FC3 output: [64, 100]
# [0305 11:28:19 @registry.py:126] gen/LSTM/01/FC input: [64, 100]
# [0305 11:28:20 @registry.py:134] gen/LSTM/01/FC output: [64, 100]
# [0305 11:28:20 @registry.py:126] gen/LSTM/01/FC2 input: [64, 100]
# [0305 11:28:20 @registry.py:134] gen/LSTM/01/FC2 output: [64, 1993634]
# [0305 11:28:20 @registry.py:126] gen/LSTM/01/FC3 input: [64, 1993634]
# [0305 11:28:20 @registry.py:134] gen/LSTM/01/FC3 output: [64, 100]
# [0305 11:28:20 @registry.py:126] gen/LSTM/02/FC input: [64, 100]
# [0305 11:28:20 @registry.py:134] gen/LSTM/02/FC output: [64, 100]
# [0305 11:28:20 @registry.py:126] gen/LSTM/02/FC2 input: [64, 100]
# [0305 11:28:20 @registry.py:134] gen/LSTM/02/FC2 output: [64, 16940]
# [0305 11:28:20 @registry.py:126] gen/LSTM/02/FC3 input: [64, 16940]
# [0305 11:28:20 @registry.py:134] gen/LSTM/02/FC3 output: [64, 100]
# [0305 11:28:20 @registry.py:126] gen/LSTM/03/FC input: [64, 100]
# [0305 11:28:20 @registry.py:134] gen/LSTM/03/FC output: [64, 100]
# [0305 11:28:20 @registry.py:126] gen/LSTM/03/FC2 input: [64, 100]
# [0305 11:28:20 @registry.py:134] gen/LSTM/03/FC2 output: [64, 5]
# [0305 11:28:20 @registry.py:126] gen/LSTM/03/FC3 input: [64, 5]
# [0305 11:28:20 @registry.py:134] gen/LSTM/03/FC3 output: [64, 100]
# [0305 11:28:20 @registry.py:126] gen/LSTM/04/FC input: [64, 100]
# [0305 11:28:20 @registry.py:134] gen/LSTM/04/FC output: [64, 100]
# [0305 11:28:20 @registry.py:126] gen/LSTM/04/FC2 input: [64, 100]
# [0305 11:28:20 @registry.py:134] gen/LSTM/04/FC2 output: [64, 1910]
# [0305 11:28:20 @registry.py:126] gen/LSTM/04/FC3 input: [64, 1910]
# [0305 11:28:20 @registry.py:134] gen/LSTM/04/FC3 output: [64, 100]
# [0305 11:28:20 @registry.py:126] gen/LSTM/05/FC input: [64, 100]
# [0305 11:28:20 @registry.py:134] gen/LSTM/05/FC output: [64, 100]
# [0305 11:28:20 @registry.py:126] gen/LSTM/05/FC2 input: [64, 100]
# [0305 11:28:20 @registry.py:134] gen/LSTM/05/FC2 output: [64, 43047]
# [0305 11:28:20 @registry.py:126] gen/LSTM/05/FC3 input: [64, 43047]
# [0305 11:28:20 @registry.py:134] gen/LSTM/05/FC3 output: [64, 100]
# [0305 11:28:20 @registry.py:126] gen/LSTM/06/FC input: [64, 100]
# [0305 11:28:20 @registry.py:134] gen/LSTM/06/FC output: [64, 100]
# [0305 11:28:20 @registry.py:126] gen/LSTM/06/FC2 input: [64, 100]
# [0305 11:28:20 @registry.py:134] gen/LSTM/06/FC2 output: [64, 2]
# [0305 11:28:20 @registry.py:126] gen/LSTM/06/FC3 input: [64, 2]
# [0305 11:28:21 @registry.py:134] gen/LSTM/06/FC3 output: [64, 100]
# [0305 11:28:21 @registry.py:126] gen/LSTM/07/FC input: [64, 100]
# [0305 11:28:21 @registry.py:134] gen/LSTM/07/FC output: [64, 100]
# [0305 11:28:21 @registry.py:126] gen/LSTM/07/FC2 input: [64, 100]
# [0305 11:28:21 @registry.py:134] gen/LSTM/07/FC2 output: [64, 2]
# [0305 11:28:21 @registry.py:126] gen/LSTM/07/FC3 input: [64, 2]
# [0305 11:28:21 @registry.py:134] gen/LSTM/07/FC3 output: [64, 100]
# [0305 11:28:21 @registry.py:126] gen/LSTM/08/FC input: [64, 100]
# [0305 11:28:21 @registry.py:134] gen/LSTM/08/FC output: [64, 100]
# [0305 11:28:21 @registry.py:126] gen/LSTM/08/FC2 input: [64, 100]
# [0305 11:28:21 @registry.py:134] gen/LSTM/08/FC2 output: [64, 1]
# [0305 11:28:21 @registry.py:126] gen/LSTM/08/FC3 input: [64, 1]
# [0305 11:28:21 @registry.py:134] gen/LSTM/08/FC3 output: [64, 100]
# [0305 11:28:21 @registry.py:126] gen/LSTM/09/FC input: [64, 100]
# [0305 11:28:21 @registry.py:134] gen/LSTM/09/FC output: [64, 100]
# [0305 11:28:21 @registry.py:126] gen/LSTM/09/FC2 input: [64, 100]
# [0305 11:28:21 @registry.py:134] gen/LSTM/09/FC2 output: [64, 2]
# [0305 11:28:21 @registry.py:126] gen/LSTM/09/FC3 input: [64, 2]
# [0305 11:28:21 @registry.py:134] gen/LSTM/09/FC3 output: [64, 100]
# [0305 11:28:21 @registry.py:126] gen/LSTM/10/FC input: [64, 100]
# [0305 11:28:21 @registry.py:134] gen/LSTM/10/FC output: [64, 100]
# [0305 11:28:21 @registry.py:126] gen/LSTM/10/FC2 input: [64, 100]
# [0305 11:28:21 @registry.py:134] gen/LSTM/10/FC2 output: [64, 2]
# [0305 11:28:21 @registry.py:126] gen/LSTM/10/FC3 input: [64, 2]
# [0305 11:28:21 @registry.py:134] gen/LSTM/10/FC3 output: [64, 100]
# [0305 11:28:22 @registry.py:126] gen/LSTM/11/FC input: [64, 100]
# [0305 11:28:22 @registry.py:134] gen/LSTM/11/FC output: [64, 100]
# [0305 11:28:22 @registry.py:126] gen/LSTM/11/FC2 input: [64, 100]
# [0305 11:28:22 @registry.py:134] gen/LSTM/11/FC2 output: [64, 2]
# [0305 11:28:22 @registry.py:126] gen/LSTM/11/FC3 input: [64, 2]
# [0305 11:28:22 @registry.py:134] gen/LSTM/11/FC3 output: [64, 100]
# [0305 11:28:22 @registry.py:126] gen/LSTM/12/FC input: [64, 100]
# [0305 11:28:22 @registry.py:134] gen/LSTM/12/FC output: [64, 100]
# [0305 11:28:22 @registry.py:126] gen/LSTM/12/FC2 input: [64, 100]
# [0305 11:28:22 @registry.py:134] gen/LSTM/12/FC2 output: [64, 2]
# [0305 11:28:22 @registry.py:126] gen/LSTM/12/FC3 input: [64, 2]
# [0305 11:28:22 @registry.py:134] gen/LSTM/12/FC3 output: [64, 100]
# [0305 11:28:22 @registry.py:126] gen/LSTM/13/FC input: [64, 100]
# [0305 11:28:22 @registry.py:134] gen/LSTM/13/FC output: [64, 100]
# [0305 11:28:22 @registry.py:126] gen/LSTM/13/FC2 input: [64, 100]
# [0305 11:28:22 @registry.py:134] gen/LSTM/13/FC2 output: [64, 2]
# [0305 11:28:22 @registry.py:126] gen/LSTM/13/FC3 input: [64, 2]
# [0305 11:28:22 @registry.py:134] gen/LSTM/13/FC3 output: [64, 100]
# [0305 11:28:22 @registry.py:126] gen/LSTM/14/FC input: [64, 100]
# [0305 11:28:22 @registry.py:134] gen/LSTM/14/FC output: [64, 100]
# [0305 11:28:22 @registry.py:126] gen/LSTM/14/FC2 input: [64, 100]
# [0305 11:28:22 @registry.py:134] gen/LSTM/14/FC2 output: [64, 4]
# [0305 11:28:22 @registry.py:126] gen/LSTM/14/FC3 input: [64, 4]
# [0305 11:28:22 @registry.py:134] gen/LSTM/14/FC3 output: [64, 100]
# [0305 11:28:22 @registry.py:126] gen/LSTM/15/FC input: [64, 100]
# [0305 11:28:22 @registry.py:134] gen/LSTM/15/FC output: [64, 100]
# [0305 11:28:22 @registry.py:126] gen/LSTM/15/FC2 input: [64, 100]
# [0305 11:28:22 @registry.py:134] gen/LSTM/15/FC2 output: [64, 5]
# [0305 11:28:22 @registry.py:126] gen/LSTM/15/FC3 input: [64, 5]
# [0305 11:28:22 @registry.py:134] gen/LSTM/15/FC3 output: [64, 100]
# [0305 11:28:22 @registry.py:126] gen/LSTM/16/FC input: [64, 100]
# [0305 11:28:22 @registry.py:134] gen/LSTM/16/FC output: [64, 100]
# [0305 11:28:22 @registry.py:126] gen/LSTM/16/FC2 input: [64, 100]
# [0305 11:28:22 @registry.py:134] gen/LSTM/16/FC2 output: [64, 5]
# [0305 11:28:22 @registry.py:126] gen/LSTM/16/FC3 input: [64, 5]
# [0305 11:28:22 @registry.py:134] gen/LSTM/16/FC3 output: [64, 100]
# [0305 11:28:23 @registry.py:126] gen/LSTM/17/FC input: [64, 100]
# [0305 11:28:23 @registry.py:134] gen/LSTM/17/FC output: [64, 100]
# [0305 11:28:23 @registry.py:126] gen/LSTM/17/FC2 input: [64, 100]
# [0305 11:28:23 @registry.py:134] gen/LSTM/17/FC2 output: [64, 18]
# [0305 11:28:23 @registry.py:126] gen/LSTM/17/FC3 input: [64, 18]
# [0305 11:28:23 @registry.py:134] gen/LSTM/17/FC3 output: [64, 100]
# [0305 11:28:23 @registry.py:126] discrim/dis_fc0/fc input: [64, 4449155]
# [0305 11:28:23 @registry.py:134] discrim/dis_fc0/fc output: [64, 100]
# [0305 11:28:23 @registry.py:126] discrim/dis_fc0/fc_diversity input: [64, 100]
# [0305 11:28:23 @registry.py:134] discrim/dis_fc0/fc_diversity output: [64, 100]
# [0305 11:28:23 @registry.py:126] discrim/dis_fc_top input: [64, 110]
# [0305 11:28:23 @registry.py:134] discrim/dis_fc_top output: [64, 1]
#
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# [0305 11:28:35 @logger.py:83] Existing log file 'output\logs\log.log' backuped to 'output\logs\log.log.0305-112835'
# [0305 11:28:35 @logger.py:90] Argv: c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\ipykernel_launcher.py --f=c:\Users\cupca\AppData\Roaming\jupyter\runtime\kernel-v2-23584DUMEnjJi6t6r.json
# [0305 11:28:35 @model_utils.py:67] List of Trainable Variables:
# name                              shape             #elements
# --------------------------------  --------------  -----------
# gen/LSTM/go:0                     [1, 100]                100
# gen/LSTM/lstm_cell/kernel:0       [500, 400]           200000
# gen/LSTM/lstm_cell/bias:0         [400]                   400
# gen/LSTM/00/FC/W:0                [100, 100]            10000
# gen/LSTM/00/FC/b:0                [100]                   100
# gen/LSTM/00/FC2/W:0               [100, 2393572]    239357200
# gen/LSTM/00/FC2/b:0               [2393572]           2393572
# gen/LSTM/00/FC3/W:0               [2393572, 100]    239357200
# gen/LSTM/00/FC3/b:0               [100]                   100
# gen/LSTM/00/attw:0                [1, 1, 1]                 1
# gen/LSTM/01/FC/W:0                [100, 100]            10000
# gen/LSTM/01/FC/b:0                [100]                   100
# gen/LSTM/01/FC2/W:0               [100, 1993634]    199363400
# gen/LSTM/01/FC2/b:0               [1993634]           1993634
# gen/LSTM/01/FC3/W:0               [1993634, 100]    199363400
# gen/LSTM/01/FC3/b:0               [100]                   100
# gen/LSTM/01/attw:0                [2, 1, 1]                 2
# gen/LSTM/02/FC/W:0                [100, 100]            10000
# gen/LSTM/02/FC/b:0                [100]                   100
# gen/LSTM/02/FC2/W:0               [100, 16940]        1694000
# gen/LSTM/02/FC2/b:0               [16940]               16940
# gen/LSTM/02/FC3/W:0               [16940, 100]        1694000
# gen/LSTM/02/FC3/b:0               [100]                   100
# gen/LSTM/02/attw:0                [3, 1, 1]                 3
# gen/LSTM/03/FC/W:0                [100, 100]            10000
# gen/LSTM/03/FC/b:0                [100]                   100
# gen/LSTM/03/FC2/W:0               [100, 5]                500
# gen/LSTM/03/FC2/b:0               [5]                       5
# gen/LSTM/03/FC3/W:0               [5, 100]                500
# gen/LSTM/03/FC3/b:0               [100]                   100
# gen/LSTM/03/attw:0                [4, 1, 1]                 4
# gen/LSTM/04/FC/W:0                [100, 100]            10000
# gen/LSTM/04/FC/b:0                [100]                   100
# gen/LSTM/04/FC2/W:0               [100, 1910]          191000
# gen/LSTM/04/FC2/b:0               [1910]                 1910
# gen/LSTM/04/FC3/W:0               [1910, 100]          191000
# gen/LSTM/04/FC3/b:0               [100]                   100
# gen/LSTM/04/attw:0                [5, 1, 1]                 5
# gen/LSTM/05/FC/W:0                [100, 100]            10000
# gen/LSTM/05/FC/b:0                [100]                   100
# gen/LSTM/05/FC2/W:0               [100, 43047]        4304700
# gen/LSTM/05/FC2/b:0               [43047]               43047
# gen/LSTM/05/FC3/W:0               [43047, 100]        4304700
# gen/LSTM/05/FC3/b:0               [100]                   100
# gen/LSTM/05/attw:0                [6, 1, 1]                 6
# gen/LSTM/06/FC/W:0                [100, 100]            10000
# gen/LSTM/06/FC/b:0                [100]                   100
# gen/LSTM/06/FC2/W:0               [100, 2]                200
# gen/LSTM/06/FC2/b:0               [2]                       2
# gen/LSTM/06/FC3/W:0               [2, 100]                200
# gen/LSTM/06/FC3/b:0               [100]                   100
# gen/LSTM/06/attw:0                [7, 1, 1]                 7
# gen/LSTM/07/FC/W:0                [100, 100]            10000
# gen/LSTM/07/FC/b:0                [100]                   100
# gen/LSTM/07/FC2/W:0               [100, 2]                200
# gen/LSTM/07/FC2/b:0               [2]                       2
# gen/LSTM/07/FC3/W:0               [2, 100]                200
# gen/LSTM/07/FC3/b:0               [100]                   100
# gen/LSTM/07/attw:0                [8, 1, 1]                 8
# gen/LSTM/08/FC/W:0                [100, 100]            10000
# gen/LSTM/08/FC/b:0                [100]                   100
# gen/LSTM/08/FC2/W:0               [100, 1]                100
# gen/LSTM/08/FC2/b:0               [1]                       1
# gen/LSTM/08/FC3/W:0               [1, 100]                100
# gen/LSTM/08/FC3/b:0               [100]                   100
# gen/LSTM/08/attw:0                [9, 1, 1]                 9
# gen/LSTM/09/FC/W:0                [100, 100]            10000
# gen/LSTM/09/FC/b:0                [100]                   100
# gen/LSTM/09/FC2/W:0               [100, 2]                200
# gen/LSTM/09/FC2/b:0               [2]                       2
# gen/LSTM/09/FC3/W:0               [2, 100]                200
# gen/LSTM/09/FC3/b:0               [100]                   100
# gen/LSTM/09/attw:0                [10, 1, 1]               10
# gen/LSTM/10/FC/W:0                [100, 100]            10000
# gen/LSTM/10/FC/b:0                [100]                   100
# gen/LSTM/10/FC2/W:0               [100, 2]                200
# gen/LSTM/10/FC2/b:0               [2]                       2
# gen/LSTM/10/FC3/W:0               [2, 100]                200
# gen/LSTM/10/FC3/b:0               [100]                   100
# gen/LSTM/10/attw:0                [11, 1, 1]               11
# gen/LSTM/11/FC/W:0                [100, 100]            10000
# gen/LSTM/11/FC/b:0                [100]                   100
# gen/LSTM/11/FC2/W:0               [100, 2]                200
# gen/LSTM/11/FC2/b:0               [2]                       2
# gen/LSTM/11/FC3/W:0               [2, 100]                200
# gen/LSTM/11/FC3/b:0               [100]                   100
# gen/LSTM/11/attw:0                [12, 1, 1]               12
# gen/LSTM/12/FC/W:0                [100, 100]            10000
# gen/LSTM/12/FC/b:0                [100]                   100
# gen/LSTM/12/FC2/W:0               [100, 2]                200
# gen/LSTM/12/FC2/b:0               [2]                       2
# gen/LSTM/12/FC3/W:0               [2, 100]                200
# gen/LSTM/12/FC3/b:0               [100]                   100
# gen/LSTM/12/attw:0                [13, 1, 1]               13
# gen/LSTM/13/FC/W:0                [100, 100]            10000
# gen/LSTM/13/FC/b:0                [100]                   100
# gen/LSTM/13/FC2/W:0               [100, 2]                200
# gen/LSTM/13/FC2/b:0               [2]                       2
# gen/LSTM/13/FC3/W:0               [2, 100]                200
# gen/LSTM/13/FC3/b:0               [100]                   100
# gen/LSTM/13/attw:0                [14, 1, 1]               14
# gen/LSTM/14/FC/W:0                [100, 100]            10000
# gen/LSTM/14/FC/b:0                [100]                   100
# gen/LSTM/14/FC2/W:0               [100, 4]                400
# gen/LSTM/14/FC2/b:0               [4]                       4
# gen/LSTM/14/FC3/W:0               [4, 100]                400
# gen/LSTM/14/FC3/b:0               [100]                   100
# gen/LSTM/14/attw:0                [15, 1, 1]               15
# gen/LSTM/15/FC/W:0                [100, 100]            10000
# gen/LSTM/15/FC/b:0                [100]                   100
# gen/LSTM/15/FC2/W:0               [100, 5]                500
# gen/LSTM/15/FC2/b:0               [5]                       5
# gen/LSTM/15/FC3/W:0               [5, 100]                500
# gen/LSTM/15/FC3/b:0               [100]                   100
# gen/LSTM/15/attw:0                [16, 1, 1]               16
# gen/LSTM/16/FC/W:0                [100, 100]            10000
# gen/LSTM/16/FC/b:0                [100]                   100
# gen/LSTM/16/FC2/W:0               [100, 5]                500
# gen/LSTM/16/FC2/b:0               [5]                       5
# gen/LSTM/16/FC3/W:0               [5, 100]                500
# gen/LSTM/16/FC3/b:0               [100]                   100
# gen/LSTM/16/attw:0                [17, 1, 1]               17
# gen/LSTM/17/FC/W:0                [100, 100]            10000
# gen/LSTM/17/FC/b:0                [100]                   100
# gen/LSTM/17/FC2/W:0               [100, 18]              1800
# gen/LSTM/17/FC2/b:0               [18]                     18
# gen/LSTM/17/FC3/W:0               [18, 100]              1800
# gen/LSTM/17/FC3/b:0               [100]                   100
# gen/LSTM/17/attw:0                [18, 1, 1]               18
# discrim/dis_fc0/fc/W:0            [4449155, 100]    444915500
# discrim/dis_fc0/fc/b:0            [100]                   100
# discrim/dis_fc0/fc_diversity/W:0  [100, 100]            10000
# discrim/dis_fc0/fc_diversity/b:0  [100]                   100
# discrim/dis_fc0/bn/beta:0         [110]                   110
# discrim/dis_fc_top/W:0            [110, 1]                110
# discrim/dis_fc_top/b:0            [1]                       1
# Number of trainable variables: 136
# Number of parameters (elements): 1339590347
# Storage space needed for all trainable variables: 5110.13MB
# [0305 11:28:35 @base.py:209] Setup callbacks graph ...
# [0305 11:28:36 @summary.py:46] [MovingAverageSummary] 6 operations in collection 'MOVING_SUMMARY_OPS' will be run with session hooks.
# [0305 11:28:36 @summary.py:93] Summarizing collection 'summaries' of size 9.
# [0305 11:28:36 @graph.py:98] Applying collection UPDATE_OPS of 4 ops.
# [0305 11:28:57 @base.py:230] Creating the session ...
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#
# c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\tensorflow\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1318       return self._call_tf_sessionrun(
# -> 1319           options, feed_dict, fetch_list, target_list, run_metadata)
#    1320
#
# c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\tensorflow\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1406         self._session, options, feed_dict, fetch_list, target_list,
# -> 1407         run_metadata)
#    1408
#
# ResourceExhaustedError: OOM when allocating tensor of shape [4449155,100] and type float
# 	 [[{{node discrim/dis_fc0/fc/W/Adam_1/Initializer/zeros}}]]
#
# During handling of the above exception, another exception occurred:
#
# ResourceExhaustedError                    Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22176\1779021956.py in <module>
# ----> 1 tgan.fit(data)
#
# c:\Users\cupca\Desktop\Thesis\thesis-project\TGAN\tgan\model.py in fit(self, data)
#     714             max_epoch=self.max_epoch,
#     715             session_init=session_init,
# --> 716             starting_epoch=starting_epoch
#     717         )
#     718
#
# c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\tensorpack\train\base.py in train_with_defaults(self, _sentinel, callbacks, monitors, session_creator, session_init, steps_per_epoch, starting_epoch, max_epoch, extra_callbacks)
#     342         self.train(callbacks, monitors,
#     343                    session_creator, session_init,
# --> 344                    steps_per_epoch, starting_epoch, max_epoch)
#     345
#     346     def __new__(cls, *args, **kwargs):
#
# c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\tensorpack\train\base.py in train(self, callbacks, monitors, session_creator, session_init, steps_per_epoch, starting_epoch, max_epoch)
#     313         """
#     314         self.setup_callbacks(callbacks, monitors)
# --> 315         self.initialize(session_creator, session_init)
#     316         self.main_loop(steps_per_epoch, starting_epoch, max_epoch)
#     317
#
# c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\tensorpack\utils\argtools.py in wrapper(*args, **kwargs)
#     174         cache.add(func)
#     175
# --> 176         return func(*args, **kwargs)
#     177
#     178     return wrapper
#
# c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\tensorpack\train\tower.py in initialize(self, session_creator, session_init)
#     150     @call_only_once
#     151     def initialize(self, session_creator, session_init):
# --> 152         super(TowerTrainer, self).initialize(session_creator, session_init)
#     153         # Predictors are created before creating the session, so they don't have an associated session.
#     154         for pred in self._predictors:
#
# c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\tensorpack\utils\argtools.py in wrapper(*args, **kwargs)
#     174         cache.add(func)
#     175
# --> 176         return func(*args, **kwargs)
#     177
#     178     return wrapper
#
# c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\tensorpack\train\base.py in initialize(self, session_creator, session_init)
#     230         logger.info("Creating the session ...")
#     231
# --> 232         self.sess = session_creator.create_session()
#     233         self.initialize_hooks()
#     234
#
# c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\tensorpack\tfutils\sesscreate.py in create_session(self)
#      69             sess.run(op)
#      70
# ---> 71         run(tf.global_variables_initializer())
#      72         run(tf.local_variables_initializer())
#      73         run(tf.tables_initializer())
#
# c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\tensorpack\tfutils\sesscreate.py in run(op)
#      67                             "This initializer is likely to hang!".format(
#      68                                 op.name, dep_op.name))
# ---> 69             sess.run(op)
#      70
#      71         run(tf.global_variables_initializer())
#
# c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1150     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1151       results = self._do_run(handle, final_targets, final_fetches,
# -> 1152                              feed_dict_tensor, options, run_metadata)
#    1153     else:
#    1154       results = []
#
# c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1326     if handle is None:
#    1327       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1328                            run_metadata)
#    1329     else:
#    1330       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1346           pass
#    1347       message = error_interpolation.interpolate(message, self._graph)
# -> 1348       raise type(e)(node_def, op, message)
#    1349
#    1350   def _extend_graph(self):
#
# ResourceExhaustedError: OOM when allocating tensor of shape [4449155,100] and type float
# 	 [[node discrim/dis_fc0/fc/W/Adam_1/Initializer/zeros (defined at c:\Users\cupca\Desktop\Thesis\thesis-project\TGAN\tgan\trainer.py:56) ]]
#
# Caused by op 'discrim/dis_fc0/fc/W/Adam_1/Initializer/zeros', defined at:
#   File "c:\Users\cupca\anaconda3\envs\tgan_tf\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "c:\Users\cupca\anaconda3\envs\tgan_tf\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\traitlets\config\application.py", line 992, in launch_instance
#     app.start()
#   File "c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\ipykernel\kernelapp.py", line 712, in start
#     self.io_loop.start()
#   File "c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\tornado\platform\asyncio.py", line 215, in start
#     self.asyncio_loop.run_forever()
#   File "c:\Users\cupca\anaconda3\envs\tgan_tf\lib\asyncio\base_events.py", line 523, in run_forever
#     self._run_once()
#   File "c:\Users\cupca\anaconda3\envs\tgan_tf\lib\asyncio\base_events.py", line 1758, in _run_once
#     handle._run()
#   File "c:\Users\cupca\anaconda3\envs\tgan_tf\lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\ipykernel\kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\ipykernel\kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\ipykernel\kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\ipykernel\kernelbase.py", line 730, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\ipykernel\ipkernel.py", line 390, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\ipykernel\zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\IPython\core\interactiveshell.py", line 2915, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\IPython\core\interactiveshell.py", line 2960, in _run_cell
#     return runner(coro)
#   File "c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\IPython\core\async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\IPython\core\interactiveshell.py", line 3186, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\IPython\core\interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\cupca\AppData\Local\Temp\ipykernel_22176\1779021956.py", line 1, in <module>
#     tgan.fit(data)
#   File "c:\Users\cupca\Desktop\Thesis\thesis-project\TGAN\tgan\model.py", line 690, in fit
#     input_queue=input_queue,
#   File "c:\Users\cupca\Desktop\Thesis\thesis-project\TGAN\tgan\trainer.py", line 56, in __init__
#     d_min_train_op = opt.apply_gradients(d_min_grad_clip, name='d_op')
#   File "c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\tensorflow\python\training\optimizer.py", line 595, in apply_gradients
#     self._create_slots(var_list)
#   File "c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\tensorflow\python\training\adam.py", line 136, in _create_slots
#     self._zeros_slot(v, "v", self._name)
#   File "c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\tensorflow\python\training\optimizer.py", line 1153, in _zeros_slot
#     new_slot_variable = slot_creator.create_zeros_slot(var, op_name)
#   File "c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\tensorflow\python\training\slot_creator.py", line 183, in create_zeros_slot
#     colocate_with_primary=colocate_with_primary)
#   File "c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\tensorflow\python\training\slot_creator.py", line 157, in create_slot_with_initializer
#     dtype)
#   File "c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\tensorflow\python\training\slot_creator.py", line 65, in _create_slot_var
#     validate_shape=validate_shape)
#   File "c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\tensorflow\python\ops\variable_scope.py", line 1479, in get_variable
#     aggregation=aggregation)
#   File "c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\tensorflow\python\ops\variable_scope.py", line 1220, in get_variable
#     aggregation=aggregation)
#   File "c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\tensorflow\python\ops\variable_scope.py", line 547, in get_variable
#     aggregation=aggregation)
#   File "c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\tensorflow\python\ops\variable_scope.py", line 499, in _true_getter
#     aggregation=aggregation)
#   File "c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\tensorflow\python\ops\variable_scope.py", line 911, in _get_single_variable
#     aggregation=aggregation)
#   File "c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\tensorflow\python\ops\variables.py", line 213, in __call__
#     return cls._variable_v1_call(*args, **kwargs)
#   File "c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\tensorflow\python\ops\variables.py", line 176, in _variable_v1_call
#     aggregation=aggregation)
#   File "c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\tensorflow\python\ops\variables.py", line 155, in <lambda>
#     previous_getter = lambda **kwargs: default_variable_creator(None, **kwargs)
#   File "c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\tensorflow\python\ops\variable_scope.py", line 2495, in default_variable_creator
#     expected_shape=expected_shape, import_scope=import_scope)
#   File "c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\tensorflow\python\ops\variables.py", line 217, in __call__
#     return super(VariableMetaclass, cls).__call__(*args, **kwargs)
#   File "c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\tensorflow\python\ops\variables.py", line 1395, in __init__
#     constraint=constraint)
#   File "c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\tensorflow\python\ops\variables.py", line 1503, in _init_from_args
#     initial_value(), name="initial_value", dtype=dtype)
#   File "c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\tensorflow\python\ops\variable_scope.py", line 883, in <lambda>
#     shape.as_list(), dtype=dtype, partition_info=partition_info)
#   File "c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\tensorflow\python\ops\init_ops.py", line 110, in __call__
#     return array_ops.zeros(shape, dtype)
#   File "c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\tensorflow\python\ops\array_ops.py", line 1817, in zeros
#     output = fill(shape, constant(zero, dtype=dtype), name=name)
#   File "c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\tensorflow\python\ops\gen_array_ops.py", line 3367, in fill
#     "Fill", dims=dims, value=value, name=name)
#   File "c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\tensorflow\python\framework\op_def_library.py", line 788, in _apply_op_helper
#     op_def=op_def)
#   File "c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\tensorflow\python\util\deprecation.py", line 507, in new_func
#     return func(*args, **kwargs)
#   File "c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\tensorflow\python\framework\ops.py", line 3300, in create_op
#     op_def=op_def)
#   File "c:\Users\cupca\anaconda3\envs\tgan_tf\lib\site-packages\tensorflow\python\framework\ops.py", line 1801, in __init__
#     self._traceback = tf_stack.extract_stack()
#
# ResourceExhaustedError (see above for traceback): OOM when allocating tensor of shape [4449155,100] and type float
# 	 [[node discrim/dis_fc0/fc/W/Adam_1/Initializer/zeros (defined at c:\Users\cupca\Desktop\Thesis\thesis-project\TGAN\tgan\trainer.py:56) ]]

# %% [markdown]
# ### 4. Sample new data
#
# After the model has been fit, we are ready to generate new samples by calling the `TGANModel.sample`
# method passing it the desired amount of samples.
#
# The returned object, `samples`, is a `pandas.DataFrame` containing a table of synthetic data with
# the same format as the input data and 1000 rows as we requested.

# %%
num_samples = 1000

samples = tgan.sample(num_samples)

samples.head(3)

# %% [markdown]
# ### 5. Save and Load a model
#
# In the steps above we saw that the fitting process is slow, so we probably would like to avoid having to fit every we want to generate samples. Instead we can fit a model once, save it, and load it every time we want to sample new data.
#
# If we have a fitted model, we can save it by calling the `TGANModel.save` method, that only takes
# as argument the path to store the model into. Similarly, the `TGANModel.load` allows to load a model stored on disk by passing as argument a path where the model is stored.
#
# At this point we could use this model instance to generate more samples.

# %%
model_path = 'demo/my_model'

tgan.save(model_path)

# %%
new_tgan = TGANModel.load(model_path)

# %%
new_samples = new_tgan.sample(num_samples)

new_samples.head(3)

# %% [markdown]
# ## Loading custom datasets
#
# In the previous steps we used some demonstration data but we did not show how to load your own dataset.
#
# In order to do so you can use `pandas.read_csv` by passing it the path to the CSV file that you want to load.
#
# Additionally, you will need to create 0-indexed list of columns indices to be considered continuous.
#
# For example, if we want to load a local CSV file, `path/to/my.csv`, that has as continuous columns their first 4 columns, that is, indices `[0,1,2,3]`, we would do it like this:

# %%
import pandas as pd

data = pd.read_csv('data/census.csv')

continuous_columns = [0,1,2,3]

# %% [markdown]
# ## Model Parameters
#
# If you want to change the default behavior of TGANModel, such as as different `batch_size` or
# `num_epochs`, you can do so by passing different arguments when creating the instance. Have b
#
# ### Model general behavior
#
# * continous_columns (`list[int]`, required): List of columns to be considered continuous.
# * output (`str`, default=`output`): Path to store the model and its artifacts.
# * gpu (`list[str]`, default=`[]`): Comma separated list of GPU(s) to use.
#
# ### Neural network definition and fitting
#
# * max_epoch (`int`, default=`100`): Number of epochs to use during training.
# * steps_per_epoch (`int`, default=`10000`): Number of steps to run on each epoch.
# * save_checkpoints(`bool`, default=True): Whether or not to store checkpoints of the model after each training epoch.
# * restore_session(`bool`, default=True): Whether or not continue training from the last checkpoint.
# * batch_size (`int`, default=`200`): Size of the batch to feed the model at each step.
# * z_dim (`int`, default=`100`): Number of dimensions in the noise input for the generator.
# * noise (`float`, default=`0.2`): Upper bound to the gaussian noise added to categorical columns.
# * l2norm (`float`, default=`0.00001`): L2 reguralization coefficient when computing losses.
# * learning_rate (`float`, default=`0.001`): Learning rate for the optimizer.
# * num_gen_rnn (`int`, default=`400`):
# * num_gen_feature (`int`, default=`100`): Number of features of in the generator.
# * num_dis_layers (`int`, default=`2`):
# * num_dis_hidden (`int`, default=`200`):
# * optimizer (`str`, default=`AdamOptimizer`): Name of the optimizer to use during `fit`, possible
#   values are: [`GradientDescentOptimizer`, `AdamOptimizer`, `AdadeltaOptimizer`].
#
# If we wanted to create an identical instance to the one created on step 2, but passing the arguments in a explicit way we will do something like this:

# %%
tgan = TGANModel(
    continuous_columns,
    output='output',
    gpu=None,
    max_epoch=5,
    steps_per_epoch=10000,
    save_checkpoints=True,
    restore_session=True,
    batch_size=64,
    z_dim=200,
    noise=0.2,
    l2norm=0.00001,
    learning_rate=0.001,
    num_gen_rnn=100,
    num_gen_feature=100,
    num_dis_layers=1,
    num_dis_hidden=100,
    optimizer='AdamOptimizer'
)

# %% [markdown]
# ## Command-line interface
#
# We include a command-line interface that allows users to access TGAN functionality. Currently only one action is supported.
#
# ### Random hyperparameter search
#
# #### Input
#
# To run random searchs for the best model hyperparameters for a given dataset, we will need:
#
# * A dataset, in a csv file, without any missing value, only columns of type `bool`, `str`, `int` or
#   `float` and only one type for column, as specified in [Data Format Input](#data-format-input).
#
# * A JSON file containing the configuration for the search. This configuration shall contain:
#
#   * `name`: Name of the experiment. A folder with this name will be created.
#   * `num_random_search`: Number of iterations in hyper parameter search.
#   * `train_csv`: Path to the csv file containing the dataset.
#   * `continuous_cols`: List of column indices, starting at 0, to be considered continuous.
#   * `epoch`: Number of epoches to train the model.
#   * `steps_per_epoch`: Number of optimization steps in each epoch.
#   * `sample_rows`: Number of rows to sample when evaluating the model.
#
# You can see an example of such a json file in [examples/config.json](examples/config.json), which you
# can download and use as a template.
#
# #### Execution
#
# Once we have prepared everything we can launch the random hyperparameter search with this command:
#
# ``` bash
# tgan experiments config.json results.json
# ```
#
# Where the first argument, `config.json`,  is the path to your configuration JSON, and the second,
# `results.json`, is the path to store the summary of the execution.
#
# This will run the random search, wich basically consist of the folling steps:
#
# 1. We fetch and split our data between test and train.
# 2. We randomly select the hyperparameters to test.
# 3. Then, for each hyperparameter combination, we train a TGAN model using the real training data T
#    and generate a synthetic training dataset Tsynth.
# 4. We then train machine learning models on both the real and synthetic datasets.
# 5. We use these trained models on real test data and see how well they perform.
#
# #### Output
#
# One the experiment has finished, the following can be found:
#
# * A JSON file, in the example above called `results.json`, containing a summary of the experiments.
#   This JSON will contain a key for each experiment `name`, and on it, an array of length
#   `num_random_search`, with the selected parameters and its evaluation score. For a configuration
#   like the example, the summary will look like this:
#
# ``` python
# {
#     'census': [
#         {
#             "steps_per_epoch" : 10000,
#             "num_gen_feature" : 300,
#             "num_dis_hidden" : 300,
#             "batch_size" : 100,
#             "num_gen_rnn" : 400,
#             "score" : 0.937802280415988,
#             "max_epoch" : 5,
#             "num_dis_layers" : 4,
#             "learning_rate" : 0.0002,
#             "z_dim" : 100,
#             "noise" : 0.2
#         },
#         ... # 9 more nodes
#     ]
# }
# ```
#
# * A set of folders, each one names after the `name` specified in the JSON configuration, contained
# in the `experiments` folder. In each folder, sampled data and the models can be found. For a configuration
# like the example, this will look like this:
#
# ```
# experiments/
#   census/
#     data/       # Sampled data with each of the models in the random search.
#     model_0/
#       logs/     # Training logs
#       model/    # Tensorflow model checkpoints
#     model_1/    # 9 more folders, one for each model in the random search
#     ...
# ```

# %% [markdown]
# ## Citation
#
# If you use TGAN, please cite the following work:
#
# > Lei Xu, Kalyan Veeramachaneni. 2018. Synthesizing Tabular Data using Generative Adversarial Networks.
#
# ```LaTeX
# @article{xu2018synthesizing,
#   title={Synthesizing Tabular Data using Generative Adversarial Networks},
#   author={Xu, Lei and Veeramachaneni, Kalyan},
#   journal={arXiv preprint arXiv:1811.11264},
#   year={2018}
# }
# ```
# You can find the original paper [here](https://arxiv.org/pdf/1811.11264.pdf)
