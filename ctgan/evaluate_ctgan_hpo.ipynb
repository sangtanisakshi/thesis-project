# %% [markdown]
# # Re-run the Evaluation for CTGAN

# %%
import pandas as pd

ctgan_synthetic_data = []
import os
for dirname, _, filenames in os.walk("..\\thesisgan\\output\\CTGAN_HPO\\"):
    for filename in filenames:
        if 'syn' in filename:
            fx = os.path.join(dirname, filename)
            ctgan_synthetic_data.append(fx)            
            print(fx)
# Out:
# ..\thesisgan\output\CTGAN_HPO\0\syn.csv
# ..\thesisgan\output\CTGAN_HPO\1\syn.csv
# ..\thesisgan\output\CTGAN_HPO\10\syn.csv
# ..\thesisgan\output\CTGAN_HPO\11\syn.csv
# ..\thesisgan\output\CTGAN_HPO\12\syn.csv
# ..\thesisgan\output\CTGAN_HPO\13\syn.csv
# ..\thesisgan\output\CTGAN_HPO\14\syn.csv
# ..\thesisgan\output\CTGAN_HPO\15\syn.csv
# ..\thesisgan\output\CTGAN_HPO\16\syn.csv
# ..\thesisgan\output\CTGAN_HPO\17\syn.csv
# ..\thesisgan\output\CTGAN_HPO\18\syn.csv
# ..\thesisgan\output\CTGAN_HPO\19\syn.csv
# ..\thesisgan\output\CTGAN_HPO\2\syn.csv
# ..\thesisgan\output\CTGAN_HPO\3\syn.csv
# ..\thesisgan\output\CTGAN_HPO\4\syn.csv
# ..\thesisgan\output\CTGAN_HPO\5\syn.csv
# ..\thesisgan\output\CTGAN_HPO\6\syn.csv
# ..\thesisgan\output\CTGAN_HPO\7\syn.csv
# ..\thesisgan\output\CTGAN_HPO\8\syn.csv
# ..\thesisgan\output\CTGAN_HPO\9\syn.csv

# %%
real_data = pd.read_csv("..\\thesisgan\\input\\new_hpo_data.csv")
test_data = pd.read_csv("..\\thesisgan\\input\\new_test_data.csv")
import sys
sys.path.append("..")
from ctabganplus.model.evaluation import get_utility_metrics

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le_dict = {"attack_type": "le_attack_type", "label": "le_label", "proto": "le_proto", "tos": "le_tos"}
for c in le_dict.keys():
    le_dict[c] = LabelEncoder()
    test_data[c] = le_dict[c].fit_transform(test_data[c])
    real_data[c] = le_dict[c].fit_transform(real_data[c])

# %%
test_data.attack_type.value_counts()
# Out:
# attack_type
# 0    261660
# 2     62741
# 4      2630
# 1       253
# 3         7
# Name: count, dtype: int64

# %%
import xgboost as xgb

# %%
for synthetic_data in ctgan_synthetic_data:
    df = pd.read_csv(synthetic_data)
    for c in le_dict.keys():
        df[c] = le_dict[c].fit_transform(df[c])
    result_df, cr = get_utility_metrics(real_data, test_data, df, scaler="MinMax",type={"Classification":["xgb","lr","dt","rf","mlp"]})
    result_df["id"] = synthetic_data.split("\\")[4]
    cr["id"] = synthetic_data.split("\\")[4]
    path = synthetic_data.split("syn")[0]
    print(path)
    result_df.to_csv(path + "new_classification_results.csv", index=False)
    cr.to_csv(path + "new_classification_report.csv", index=False)
    print("Done for " + synthetic_data)
# Out:
# Model:  xgb trained on real data
# Model:  lr trained on real data
# Model:  dt trained on real data
# Model:  rf trained on real data
# Model:  mlp trained on real data
# Model:  xgb trained on fake data
# Model:  lr trained on fake data
# Model:  dt trained on fake data
# Model:  rf trained on fake data
# Model:  mlp trained on fake data
# ..\thesisgan\output\CTGAN_HPO\0\
# Done for ..\thesisgan\output\CTGAN_HPO\0\syn.csv
# Model:  xgb trained on real data
# Model:  lr trained on real data
# Model:  dt trained on real data
# Model:  rf trained on real data
# Model:  mlp trained on real data
# Model:  xgb trained on fake data
# Model:  lr trained on fake data
# Model:  dt trained on fake data
# Model:  rf trained on fake data
# Model:  mlp trained on fake data
# ..\thesisgan\output\CTGAN_HPO\1\
# Done for ..\thesisgan\output\CTGAN_HPO\1\syn.csv
# Model:  xgb trained on real data
# Model:  lr trained on real data
# Model:  dt trained on real data
# Model:  rf trained on real data
# Model:  mlp trained on real data
# Model:  xgb trained on fake data
# Model:  lr trained on fake data
# Model:  dt trained on fake data
# Model:  rf trained on fake data
# Model:  mlp trained on fake data
# ..\thesisgan\output\CTGAN_HPO\10\
# Done for ..\thesisgan\output\CTGAN_HPO\10\syn.csv
# Model:  xgb trained on real data
# Model:  lr trained on real data
# Model:  dt trained on real data
# Model:  rf trained on real data
# Model:  mlp trained on real data
# Model:  xgb trained on fake data
# Model:  lr trained on fake data
# Model:  dt trained on fake data
# Model:  rf trained on fake data
# Model:  mlp trained on fake data
# ..\thesisgan\output\CTGAN_HPO\11\
# Done for ..\thesisgan\output\CTGAN_HPO\11\syn.csv
# Model:  xgb trained on real data
# Model:  lr trained on real data
# Model:  dt trained on real data
# Model:  rf trained on real data
# Model:  mlp trained on real data
# Model:  xgb trained on fake data
# Model:  lr trained on fake data
# Model:  dt trained on fake data
# Model:  rf trained on fake data
# Model:  mlp trained on fake data
# ..\thesisgan\output\CTGAN_HPO\12\
# Done for ..\thesisgan\output\CTGAN_HPO\12\syn.csv
# Model:  xgb trained on real data
# Model:  lr trained on real data
# Model:  dt trained on real data
# Model:  rf trained on real data
# Model:  mlp trained on real data
# Model:  xgb trained on fake data
# Model:  lr trained on fake data
# Model:  dt trained on fake data
# Model:  rf trained on fake data
# Model:  mlp trained on fake data
# ..\thesisgan\output\CTGAN_HPO\13\
# Done for ..\thesisgan\output\CTGAN_HPO\13\syn.csv
# Model:  xgb trained on real data
# Model:  lr trained on real data
# Model:  dt trained on real data
# Model:  rf trained on real data
# Model:  mlp trained on real data
# Model:  xgb trained on fake data
# Model:  lr trained on fake data
# Model:  dt trained on fake data
# Model:  rf trained on fake data
# Model:  mlp trained on fake data
# ..\thesisgan\output\CTGAN_HPO\14\
# Done for ..\thesisgan\output\CTGAN_HPO\14\syn.csv
# Model:  xgb trained on real data
# Model:  lr trained on real data
# Model:  dt trained on real data
# Model:  rf trained on real data
# Model:  mlp trained on real data
# Model:  xgb trained on fake data
# Model:  lr trained on fake data
# Model:  dt trained on fake data
# Model:  rf trained on fake data
# Model:  mlp trained on fake data
# ..\thesisgan\output\CTGAN_HPO\15\
# Done for ..\thesisgan\output\CTGAN_HPO\15\syn.csv
# Model:  xgb trained on real data
# Model:  lr trained on real data
# Model:  dt trained on real data
# Model:  rf trained on real data
# Model:  mlp trained on real data
# Model:  xgb trained on fake data
# Model:  lr trained on fake data
# Model:  dt trained on fake data
# Model:  rf trained on fake data
# Model:  mlp trained on fake data
# ..\thesisgan\output\CTGAN_HPO\16\
# Done for ..\thesisgan\output\CTGAN_HPO\16\syn.csv
# Model:  xgb trained on real data
# Model:  lr trained on real data
# Model:  dt trained on real data
# Model:  rf trained on real data
# Model:  mlp trained on real data
# Model:  xgb trained on fake data
# Model:  lr trained on fake data
# Model:  dt trained on fake data
# Model:  rf trained on fake data
# Model:  mlp trained on fake data
# ..\thesisgan\output\CTGAN_HPO\17\
# Done for ..\thesisgan\output\CTGAN_HPO\17\syn.csv
# Model:  xgb trained on real data
# Model:  lr trained on real data
# Model:  dt trained on real data
# Model:  rf trained on real data
# Model:  mlp trained on real data
# Model:  xgb trained on fake data
# Model:  lr trained on fake data
# Model:  dt trained on fake data
# Model:  rf trained on fake data
# Model:  mlp trained on fake data
# ..\thesisgan\output\CTGAN_HPO\18\
# Done for ..\thesisgan\output\CTGAN_HPO\18\syn.csv
# Model:  xgb trained on real data
# Model:  lr trained on real data
# Model:  dt trained on real data
# Model:  rf trained on real data
# Model:  mlp trained on real data
# Model:  xgb trained on fake data
# Model:  lr trained on fake data
# Model:  dt trained on fake data
# Model:  rf trained on fake data
# Model:  mlp trained on fake data
# ..\thesisgan\output\CTGAN_HPO\19\
# Done for ..\thesisgan\output\CTGAN_HPO\19\syn.csv
# Model:  xgb trained on real data
# Model:  lr trained on real data
# Model:  dt trained on real data
# Model:  rf trained on real data
# Model:  mlp trained on real data
# Model:  xgb trained on fake data
# Model:  lr trained on fake data
# Model:  dt trained on fake data
# Model:  rf trained on fake data
# Model:  mlp trained on fake data
# ..\thesisgan\output\CTGAN_HPO\2\
# Done for ..\thesisgan\output\CTGAN_HPO\2\syn.csv
# Model:  xgb trained on real data
# Model:  lr trained on real data
# Model:  dt trained on real data
# Model:  rf trained on real data
# Model:  mlp trained on real data
# Model:  xgb trained on fake data
# Model:  lr trained on fake data
# Model:  dt trained on fake data
# Model:  rf trained on fake data
# Model:  mlp trained on fake data
# ..\thesisgan\output\CTGAN_HPO\3\
# Done for ..\thesisgan\output\CTGAN_HPO\3\syn.csv
# Model:  xgb trained on real data
# Model:  lr trained on real data
# Model:  dt trained on real data
# Model:  rf trained on real data
# Model:  mlp trained on real data
# Model:  xgb trained on fake data
# Model:  lr trained on fake data
# Model:  dt trained on fake data
# Model:  rf trained on fake data
# Model:  mlp trained on fake data
# ..\thesisgan\output\CTGAN_HPO\4\
# Done for ..\thesisgan\output\CTGAN_HPO\4\syn.csv
# Model:  xgb trained on real data
# Model:  lr trained on real data
# Model:  dt trained on real data
# Model:  rf trained on real data
# Model:  mlp trained on real data
# Model:  xgb trained on fake data
# Model:  lr trained on fake data
# Model:  dt trained on fake data
# Model:  rf trained on fake data
# Model:  mlp trained on fake data
# ..\thesisgan\output\CTGAN_HPO\5\
# Done for ..\thesisgan\output\CTGAN_HPO\5\syn.csv
# Model:  xgb trained on real data
# Model:  lr trained on real data
# Model:  dt trained on real data
# Model:  rf trained on real data
# Model:  mlp trained on real data
# Model:  xgb trained on fake data
# Model:  lr trained on fake data
# Model:  dt trained on fake data
# Model:  rf trained on fake data
# Model:  mlp trained on fake data
# ..\thesisgan\output\CTGAN_HPO\6\
# Done for ..\thesisgan\output\CTGAN_HPO\6\syn.csv
# Model:  xgb trained on real data
# Model:  lr trained on real data
# Model:  dt trained on real data
# Model:  rf trained on real data
# Model:  mlp trained on real data
# Model:  xgb trained on fake data
# Model:  lr trained on fake data
# Model:  dt trained on fake data
# Model:  rf trained on fake data
# Model:  mlp trained on fake data
# ..\thesisgan\output\CTGAN_HPO\7\
# Done for ..\thesisgan\output\CTGAN_HPO\7\syn.csv
# Model:  xgb trained on real data
# Model:  lr trained on real data
# Model:  dt trained on real data
# Model:  rf trained on real data
# Model:  mlp trained on real data
# Model:  xgb trained on fake data
# Model:  lr trained on fake data
# Model:  dt trained on fake data
# Model:  rf trained on fake data
# Model:  mlp trained on fake data
# ..\thesisgan\output\CTGAN_HPO\8\
# Done for ..\thesisgan\output\CTGAN_HPO\8\syn.csv
# Model:  xgb trained on real data
# Model:  lr trained on real data
# Model:  dt trained on real data
# Model:  rf trained on real data
# Model:  mlp trained on real data
# Model:  xgb trained on fake data
# Model:  lr trained on fake data
# Model:  dt trained on fake data
# Model:  rf trained on fake data
# Model:  mlp trained on fake data
# ..\thesisgan\output\CTGAN_HPO\9\
# Done for ..\thesisgan\output\CTGAN_HPO\9\syn.csv

# %% [markdown]
# # HPO Results Evaluation

# %%
import pandas as pd

ctgan_classification_report = []
ctgan_classification_results = []
import os
for dirname, _, filenames in os.walk("..\\thesisgan\\output\\CTGAN_HPO\\"):
    for filename in filenames:
        if "new_classification_report" in filename:
            fx = os.path.join(dirname, filename)
            ctgan_classification_report.append(fx)            
            print(fx)
        elif "new_classification_results" in filename:
            fx = os.path.join(dirname, filename)
            ctgan_classification_results.append(fx)
            print(fx)
# Out:
# ..\thesisgan\output\CTGAN_HPO\0\new_classification_report.csv
# ..\thesisgan\output\CTGAN_HPO\0\new_classification_results.csv
# ..\thesisgan\output\CTGAN_HPO\1\new_classification_report.csv
# ..\thesisgan\output\CTGAN_HPO\1\new_classification_results.csv
# ..\thesisgan\output\CTGAN_HPO\10\new_classification_report.csv
# ..\thesisgan\output\CTGAN_HPO\10\new_classification_results.csv
# ..\thesisgan\output\CTGAN_HPO\11\new_classification_report.csv
# ..\thesisgan\output\CTGAN_HPO\11\new_classification_results.csv
# ..\thesisgan\output\CTGAN_HPO\12\new_classification_report.csv
# ..\thesisgan\output\CTGAN_HPO\12\new_classification_results.csv
# ..\thesisgan\output\CTGAN_HPO\13\new_classification_report.csv
# ..\thesisgan\output\CTGAN_HPO\13\new_classification_results.csv
# ..\thesisgan\output\CTGAN_HPO\14\new_classification_report.csv
# ..\thesisgan\output\CTGAN_HPO\14\new_classification_results.csv
# ..\thesisgan\output\CTGAN_HPO\15\new_classification_report.csv
# ..\thesisgan\output\CTGAN_HPO\15\new_classification_results.csv
# ..\thesisgan\output\CTGAN_HPO\16\new_classification_report.csv
# ..\thesisgan\output\CTGAN_HPO\16\new_classification_results.csv
# ..\thesisgan\output\CTGAN_HPO\17\new_classification_report.csv
# ..\thesisgan\output\CTGAN_HPO\17\new_classification_results.csv
# ..\thesisgan\output\CTGAN_HPO\18\new_classification_report.csv
# ..\thesisgan\output\CTGAN_HPO\18\new_classification_results.csv
# ..\thesisgan\output\CTGAN_HPO\19\new_classification_report.csv
# ..\thesisgan\output\CTGAN_HPO\19\new_classification_results.csv
# ..\thesisgan\output\CTGAN_HPO\2\new_classification_report.csv
# ..\thesisgan\output\CTGAN_HPO\2\new_classification_results.csv
# ..\thesisgan\output\CTGAN_HPO\3\new_classification_report.csv
# ..\thesisgan\output\CTGAN_HPO\3\new_classification_results.csv
# ..\thesisgan\output\CTGAN_HPO\4\new_classification_report.csv
# ..\thesisgan\output\CTGAN_HPO\4\new_classification_results.csv
# ..\thesisgan\output\CTGAN_HPO\5\new_classification_report.csv
# ..\thesisgan\output\CTGAN_HPO\5\new_classification_results.csv
# ..\thesisgan\output\CTGAN_HPO\6\new_classification_report.csv
# ..\thesisgan\output\CTGAN_HPO\6\new_classification_results.csv
# ..\thesisgan\output\CTGAN_HPO\7\new_classification_report.csv
# ..\thesisgan\output\CTGAN_HPO\7\new_classification_results.csv
# ..\thesisgan\output\CTGAN_HPO\8\new_classification_report.csv
# ..\thesisgan\output\CTGAN_HPO\8\new_classification_results.csv
# ..\thesisgan\output\CTGAN_HPO\9\new_classification_report.csv
# ..\thesisgan\output\CTGAN_HPO\9\new_classification_results.csv

# %%
# read every json file into a dataframe and append to a main dataframe
# before appending, add the id j0cor82r from the path of the file offline-run-20240509_081254-j0cor82r for each

ctgan_classification_report_df = pd.DataFrame()
for file in ctgan_classification_report:
    cr_df = pd.read_csv(file)
    cr_df["id"] = file.split("\\")[4]
    ctgan_classification_report_df = pd.concat([ctgan_classification_report_df, cr_df])
    ctgan_classification_report_df.reset_index(drop=True, inplace=True)

# %%
pd.set_option("display.max_rows", None)

# %% [markdown]
# ### Classification Results

# %%
ctgan_classification_results_df = pd.DataFrame()
for file in ctgan_classification_results:
    cr_df = pd.read_csv(file)
    cr_df["id"] = file.split("\\")[4]
    ctgan_classification_results_df = pd.concat([ctgan_classification_results_df, cr_df])
    ctgan_classification_results_df.reset_index(drop=True, inplace=True)

# %%
ctgan_classification_results_df.drop(["Model"],axis=1).groupby(["Type","id"]).mean().sort_values(by="F1_Score", ascending=False).head(100)
# Out:
#                      Acc       AUC  F1_Score
# Type       id
# Real       9   64.538116  0.862700  0.596039
#            16  64.538116  0.862700  0.596039
#            0   64.538116  0.862700  0.596039
#            1   64.538116  0.862700  0.596039
#            10  64.538116  0.862700  0.596039
#            11  64.538116  0.862700  0.596039
#            12  64.538116  0.862700  0.596039
#            13  64.538116  0.862700  0.596039
#            14  64.538116  0.862700  0.596039
#            15  64.538116  0.862700  0.596039
#            17  64.538116  0.862700  0.596039
#            18  64.538116  0.862700  0.596039
#            19  64.538116  0.862700  0.596039
#            2   64.538116  0.862700  0.596039
#            3   64.538116  0.862700  0.596039
#            4   64.538116  0.862700  0.596039
#            5   64.538116  0.862700  0.596039
#            6   64.538116  0.862700  0.596039
#            7   64.538116  0.862700  0.596039
#            8   64.538116  0.862700  0.596039
# Fake       12  67.303971  0.857601  0.589490
#            14  65.937792  0.855984  0.579951
#            18  66.740277  0.848934  0.576094
#            0   66.699110  0.857338  0.571801
#            6   66.885550  0.854156  0.571174
#            13  63.914697  0.837394  0.568336
#            10  63.749887  0.833969  0.561950
#            19  67.627155  0.864508  0.560623
#            15  66.181461  0.866759  0.557351
#            17  65.175420  0.840377  0.540604
#            9   63.809150  0.845547  0.527567
#            3   65.596464  0.850734  0.527048
#            16  59.751987  0.817830  0.517432
#            1   50.578643  0.773854  0.506334
#            11  55.684404  0.818270  0.506112
#            8   52.672411  0.825422  0.496623
#            7   53.764416  0.799536  0.482178
#            5   49.391923  0.750252  0.464502
#            4   47.289377  0.793361  0.435962
#            2   54.355329  0.767373  0.420369
# Difference 2   10.182787  0.095327  0.175670
#            4   17.248739  0.069338  0.160077
#            5   15.146193  0.112448  0.131537
#            7   10.773701  0.063163  0.113862
#            8   11.865705  0.037277  0.099416
#            11   8.853712  0.044429  0.089927
#            1   13.959473  0.088845  0.089705
#            16   4.786129  0.044870  0.078608
#            3   -1.058348  0.011965  0.068991
#            9    0.728966  0.017152  0.068473
#            17  -0.637304  0.022323  0.055435
#            15  -1.643345 -0.004059  0.038688
#            19  -3.089039 -0.001808  0.035416
#            10   0.788229  0.028730  0.034089
#            13   0.623419  0.025306  0.027704
#            6   -2.347434  0.008544  0.024866
#            0   -2.160994  0.005361  0.024239
#            18  -2.202161  0.013765  0.019945
#            14  -1.399676  0.006715  0.016088
#            12  -2.765855  0.005099  0.006550

# %%
ctgan_classification_results_df[ctgan_classification_results_df["Type"] == "Real"].sort_values(by="Acc", ascending=False).sort_values(by="id", ascending=False).head(100)
# Out:
#            Acc       AUC  F1_Score Model  Type  id
# 229  71.365504  0.821094  0.688798    dt  Real   9
# 231  59.509164  0.864378  0.592110   mlp  Real   9
# 230  68.514053  0.939774  0.680183    rf  Real   9
# 228  46.214283  0.780573  0.490678    lr  Real   9
# 217  71.365504  0.821094  0.688798    dt  Real   8
# 219  59.509164  0.864378  0.592110   mlp  Real   8
# 216  46.214283  0.780573  0.490678    lr  Real   8
# 218  68.514053  0.939774  0.680183    rf  Real   8
# 207  59.509164  0.864378  0.592110   mlp  Real   7
# 206  68.514053  0.939774  0.680183    rf  Real   7
# 205  71.365504  0.821094  0.688798    dt  Real   7
# 204  46.214283  0.780573  0.490678    lr  Real   7
# 192  46.214283  0.780573  0.490678    lr  Real   6
# 195  59.509164  0.864378  0.592110   mlp  Real   6
# 193  71.365504  0.821094  0.688798    dt  Real   6
# 194  68.514053  0.939774  0.680183    rf  Real   6
# 181  71.365504  0.821094  0.688798    dt  Real   5
# 183  59.509164  0.864378  0.592110   mlp  Real   5
# 182  68.514053  0.939774  0.680183    rf  Real   5
# 180  46.214283  0.780573  0.490678    lr  Real   5
# 171  59.509164  0.864378  0.592110   mlp  Real   4
# 170  68.514053  0.939774  0.680183    rf  Real   4
# 168  46.214283  0.780573  0.490678    lr  Real   4
# 169  71.365504  0.821094  0.688798    dt  Real   4
# 159  59.509164  0.864378  0.592110   mlp  Real   3
# 156  46.214283  0.780573  0.490678    lr  Real   3
# 158  68.514053  0.939774  0.680183    rf  Real   3
# 157  71.365504  0.821094  0.688798    dt  Real   3
# 144  46.214283  0.780573  0.490678    lr  Real   2
# 146  68.514053  0.939774  0.680183    rf  Real   2
# 147  59.509164  0.864378  0.592110   mlp  Real   2
# 145  71.365504  0.821094  0.688798    dt  Real   2
# 132  46.214283  0.780573  0.490678    lr  Real  19
# 133  71.365504  0.821094  0.688798    dt  Real  19
# 135  59.509164  0.864378  0.592110   mlp  Real  19
# 134  68.514053  0.939774  0.680183    rf  Real  19
# 120  46.214283  0.780573  0.490678    lr  Real  18
# 123  59.509164  0.864378  0.592110   mlp  Real  18
# 122  68.514053  0.939774  0.680183    rf  Real  18
# 121  71.365504  0.821094  0.688798    dt  Real  18
# 108  46.214283  0.780573  0.490678    lr  Real  17
# 109  71.365504  0.821094  0.688798    dt  Real  17
# 110  68.514053  0.939774  0.680183    rf  Real  17
# 111  59.509164  0.864378  0.592110   mlp  Real  17
# 96   46.214283  0.780573  0.490678    lr  Real  16
# 97   71.365504  0.821094  0.688798    dt  Real  16
# 99   59.509164  0.864378  0.592110   mlp  Real  16
# 98   68.514053  0.939774  0.680183    rf  Real  16
# 87   59.509164  0.864378  0.592110   mlp  Real  15
# 84   46.214283  0.780573  0.490678    lr  Real  15
# 85   71.365504  0.821094  0.688798    dt  Real  15
# 86   68.514053  0.939774  0.680183    rf  Real  15
# 73   71.365504  0.821094  0.688798    dt  Real  14
# 75   59.509164  0.864378  0.592110   mlp  Real  14
# 72   46.214283  0.780573  0.490678    lr  Real  14
# 74   68.514053  0.939774  0.680183    rf  Real  14
# 61   71.365504  0.821094  0.688798    dt  Real  13
# 60   46.214283  0.780573  0.490678    lr  Real  13
# 62   68.514053  0.939774  0.680183    rf  Real  13
# 63   59.509164  0.864378  0.592110   mlp  Real  13
# 50   68.514053  0.939774  0.680183    rf  Real  12
# 49   71.365504  0.821094  0.688798    dt  Real  12
# 51   59.509164  0.864378  0.592110   mlp  Real  12
# 48   46.214283  0.780573  0.490678    lr  Real  12
# 37   71.365504  0.821094  0.688798    dt  Real  11
# 36   46.214283  0.780573  0.490678    lr  Real  11
# 39   59.509164  0.864378  0.592110   mlp  Real  11
# 38   68.514053  0.939774  0.680183    rf  Real  11
# 25   71.365504  0.821094  0.688798    dt  Real  10
# 26   68.514053  0.939774  0.680183    rf  Real  10
# 27   59.509164  0.864378  0.592110   mlp  Real  10
# 24   46.214283  0.780573  0.490678    lr  Real  10
# 15   59.509164  0.864378  0.592110   mlp  Real   1
# 14   68.514053  0.939774  0.680183    rf  Real   1
# 12   46.214283  0.780573  0.490678    lr  Real   1
# 13   71.365504  0.821094  0.688798    dt  Real   1
# 3    59.509164  0.864378  0.592110   mlp  Real   0
# 2    68.514053  0.939774  0.680183    rf  Real   0
# 0    46.214283  0.780573  0.490678    lr  Real   0
# 1    71.365504  0.821094  0.688798    dt  Real   0

# %%
ctgan_classification_results_df.drop(["Model"],axis=1).groupby(["id", "Type"]).mean().sort_values(by="F1_Score", ascending=False).head(100)
# Out:
#                      Acc       AUC  F1_Score
# id Type
# 9  Real        61.400751  0.851455  0.612942
# 12 Real        61.400751  0.851455  0.612942
# 5  Real        61.400751  0.851455  0.612942
# 4  Real        61.400751  0.851455  0.612942
# 3  Real        61.400751  0.851455  0.612942
# 2  Real        61.400751  0.851455  0.612942
# 19 Real        61.400751  0.851455  0.612942
# 18 Real        61.400751  0.851455  0.612942
# 17 Real        61.400751  0.851455  0.612942
# 16 Real        61.400751  0.851455  0.612942
# 15 Real        61.400751  0.851455  0.612942
# 7  Real        61.400751  0.851455  0.612942
# 14 Real        61.400751  0.851455  0.612942
# 13 Real        61.400751  0.851455  0.612942
# 6  Real        61.400751  0.851455  0.612942
# 1  Real        61.400751  0.851455  0.612942
# 10 Real        61.400751  0.851455  0.612942
# 0  Real        61.400751  0.851455  0.612942
# 8  Real        61.400751  0.851455  0.612942
# 11 Real        61.400751  0.851455  0.612942
# 9  Fake        66.464368  0.839858  0.589232
# 10 Fake        64.078340  0.824346  0.585952
# 6  Fake        65.387930  0.831914  0.584138
# 14 Fake        64.778402  0.844741  0.578009
# 13 Fake        66.468962  0.832149  0.577320
# 15 Fake        65.470027  0.846210  0.576666
# 18 Fake        62.440259  0.805348  0.574690
# 19 Fake        63.316784  0.826295  0.570804
# 16 Fake        64.522657  0.832106  0.565372
# 12 Fake        65.298366  0.830702  0.563306
# 0  Fake        62.410814  0.823344  0.560350
# 17 Fake        64.593383  0.821843  0.554302
# 3  Fake        63.624482  0.823378  0.551589
# 7  Fake        51.079206  0.765238  0.501728
# 1  Fake        52.807652  0.751193  0.499746
# 11 Fake        52.698681  0.782833  0.499405
# 5  Fake        49.180727  0.721004  0.496279
# 2  Fake        59.851802  0.789906  0.486948
# 8  Fake        47.578443  0.786415  0.473590
# 4  Fake        49.073227  0.777417  0.442015
#    Difference  12.327523  0.074038  0.170927
# 8  Difference  13.822308  0.065040  0.139353
# 2  Difference   1.548948  0.061549  0.125994
# 5  Difference  12.220024  0.130451  0.116663
# 11 Difference   8.702070  0.068621  0.113537
# 1  Difference   8.593099  0.100262  0.113196
# 7  Difference  10.321545  0.086216  0.111214
# 3  Difference  -2.223732  0.028077  0.061353
# 17 Difference  -3.192632  0.029612  0.058640
# 0  Difference  -1.010063  0.028111  0.052593
# 12 Difference  -3.897615  0.020753  0.049636
# 16 Difference  -3.121906  0.019349  0.047570
# 19 Difference  -1.916033  0.025160  0.042138
# 18 Difference  -1.039508  0.046107  0.038253
# 15 Difference  -4.069276  0.005245  0.036277
# 13 Difference  -5.068211  0.019306  0.035623
# 14 Difference  -3.377652  0.006714  0.034933
# 6  Difference  -3.987179  0.019540  0.028805
# 10 Difference  -2.677589  0.027109  0.026990
# 9  Difference  -5.063618  0.011597  0.023710
